# %%
import os
import pickle as pkl
import matplotlib.pyplot as plt

# %%
with open('OT-van-allen-probe/tuning/hidden_size.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
data
# Out:
# [{'value': 64,
#   'metrics': [{'loss': 0.8055936335272236, 'rscore': 0.30742549896240234},
#    {'loss': 0.49899805213322346, 'rscore': 0.5747936964035034}]},
#  {'value': 128,
#   'metrics': [{'loss': 0.8420188924582843, 'rscore': 0.28264689445495605},
#    {'loss': 0.49351669092007716, 'rscore': 0.565342903137207}]},
#  {'value': 256,
#   'metrics': [{'loss': 0.7894354839272784, 'rscore': 0.5990723371505737},
#    {'loss': 0.38690831805270703, 'rscore': 0.7018077373504639}]},
#  {'value': 512,
#   'metrics': [{'loss': 0.9078193428726434, 'rscore': 0.6319963932037354},
#    {'loss': 0.3594042526742332, 'rscore': 0.7436738014221191}]}]

# %%
for dat in data:
    seq_length = dat['value']
    metrics = dat['metrics']
    losses = [x['loss'] for x in metrics]
    rscores = [x['rscore'] for x in metrics] 
    
    plt.plot(range(len(rscores)), rscores, label=f"{seq_length} sequence length")
plt.title("rscore vs epochs")
plt.legend()
plt.show()
