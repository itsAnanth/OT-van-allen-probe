# %%
import os
import pickle as pkl
import matplotlib.pyplot as plt

# %%
with open('OT-van-allen-probe/tuning/seq_length.pkl', 'rb') as f:
    data = pkl.load(f)

# %%
data
# Out:
# [{'value': 500,
#   'metrics': [{'loss': 0.7958372787771233, 'rscore': 0.35342496633529663},
#    {'loss': 0.4866418423494289, 'rscore': 0.6358966827392578}]}]

# %%
for dat in data:
    seq_length = dat['value']
    metrics = dat['metrics']
    losses = [x['loss'] for x in metrics]
    rscores = [x['rscore'] for x in metrics] 
    
    plt.plot(range(len(rscores)), rscores, label=f"{seq_length} sequence length")
plt.title("rscore vs epochs")
plt.legend()
plt.show()
